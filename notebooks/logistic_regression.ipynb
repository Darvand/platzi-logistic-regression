# %% [markdown]
# # Logistic Regression for Breast Cancer Wisconsin (Diagnostic) Data Set
# ## Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("../data/data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Cleaning data
# ### Describe to understand better the data

# %%
df.iloc[:, :10].describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.iloc[:, 10:20].describe()
# Out:
#        symmetry_mean  fractal_dimension_mean   radius_se  texture_se  \
# count     569.000000              569.000000  569.000000  569.000000
# mean        0.181162                0.062798    0.405172    1.216853
# std         0.027414                0.007060    0.277313    0.551648
# min         0.106000                0.049960    0.111500    0.360200
# 25%         0.161900                0.057700    0.232400    0.833900
# 50%         0.179200                0.061540    0.324200    1.108000
# 75%         0.195700                0.066120    0.478900    1.474000
# max         0.304000                0.097440    2.873000    4.885000
#
#        perimeter_se     area_se  smoothness_se  compactness_se  concavity_se  \
# count    569.000000  569.000000     569.000000      569.000000    569.000000
# mean       2.866059   40.337079       0.007041        0.025478      0.031894
# std        2.021855   45.491006       0.003003        0.017908      0.030186
# ...

# %%
df.iloc[:, 20:].describe()
# Out:
#        symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# count   569.000000            569.000000    569.000000     569.000000
# mean      0.020542              0.003795     16.269190      25.677223
# std       0.008266              0.002646      4.833242       6.146258
# min       0.007882              0.000895      7.930000      12.020000
# 25%       0.015160              0.002248     13.010000      21.080000
# 50%       0.018730              0.003187     14.970000      25.410000
# 75%       0.023480              0.004558     18.790000      29.720000
# max       0.078950              0.029840     36.040000      49.540000
#
#        perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# ...

# %% [markdown]
# Looking at the `.csv` file, there is a comma in the end of the first line. It results in creating a new column without data. That column must be dropped with column ID, because id don't represent any useful data.

# %%
df = df.drop(['id', 'Unnamed: 32'], axis=1)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# Diagnosis column just have two values, meaning a good target for a logistic regression.
#
# ### Handle missing values

# %%
df[df.concavity_worst == 0]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 101         B        6.981         13.43           43.79      143.5
# 140         B        9.738         11.97           61.24      288.5
# 174         B       10.660         15.15           67.49      349.6
# 175         B        8.671         14.45           54.42      227.2
# 192         B        9.720         18.22           60.73      288.1
# 314         B        8.597         18.60           54.09      221.2
# 391         B        8.734         16.84           55.27      234.3
# 473         B       12.270         29.97           77.42      465.4
# 538         B        7.729         25.49           47.98      178.8
# 550         B       10.860         21.48           68.51      360.5
# 557         B        9.423         27.88           59.26      271.3
# 561         B       11.200         29.37           70.67      386.0
# 568         B        7.760         24.54           47.92      181.0
#
# ...

# %% [markdown]
# When the `concavity` value is zero, all related columns also have a value of zero. This does not make sense, as these values likely represent missing data. As there are only 13 rows with this issue, it may be best to remove them from the dataset.

# %%
df = df.replace(to_replace=[0], value=np.nan)
df.isnull().sum()
# Out:
# diagnosis                   0
# radius_mean                 0
# texture_mean                0
# perimeter_mean              0
# area_mean                   0
# smoothness_mean             0
# compactness_mean            0
# concavity_mean             13
# concave points_mean        13
# symmetry_mean               0
# fractal_dimension_mean      0
# radius_se                   0
# texture_se                  0
# perimeter_se                0
# area_se                     0
# smoothness_se               0
# compactness_se              0
# concavity_se               13
# concave points_se          13
# symmetry_se                 0
# fractal_dimension_se        0
# radius_worst                0
# texture_worst               0
# perimeter_worst             0
# area_worst                  0
# smoothness_worst            0
# compactness_worst           0
# concavity_worst            13
# concave points_worst       13
# symmetry_worst              0
# fractal_dimension_worst     0
# ...

# %%
df = df.dropna()
df.shape
# Out:
# (556, 31)

# %% [markdown]
# ### Convert tarjet variable to numeric

# %%
df.diagnosis.replace(to_replace="M", value=1, inplace=True)
df.diagnosis.replace(to_replace="B", value=0, inplace=True)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Correlation Analysis

# %%
fig = plt.figure(figsize=(15,9))
df.corr()['diagnosis'].sort_values(ascending=True).plot(kind='bar')
plt.show()

# %% [markdown]
# ## Data scalation

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = df.columns
df_scaled.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        1.0     0.504383      0.022658        0.531250   0.356389
# 1        1.0     0.630736      0.272574        0.603311   0.495838
# 2        1.0     0.587639      0.390260        0.582620   0.443062
# 3        1.0     0.182624      0.360839        0.208619   0.092551
# 4        1.0     0.617023      0.156578        0.619007   0.483395
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.553970          0.792037        0.702658             0.728615
# 1         0.220339          0.181768        0.202315             0.342707
# 2         0.466746          0.431017        0.461639             0.632301
# 3         0.792844          0.811361        0.564899             0.518430
# 4         0.374566          0.347893        0.463047             0.513915
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Data Exploration

# %%
cols = ['concave points_mean', 'radius_worst', 'perimeter_worst', 'concave points_worst', 'diagnosis']
fig = plt.figure(figsize=(10,10))
sns.pairplot(data= df[cols], hue='diagnosis')
plt.show()

# %% [markdown]
# Looking at the last correlation columns, we can see a clearly separation between diagnosis
# ## Training Logistic Binomial Model

# %%
X = df_scaled.drop('diagnosis', axis=1)
y = df_scaled['diagnosis'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
result = model.fit(X_train, y_train)

# %%
from sklearn import metrics
prediction_test = model.predict(X_test)
print(metrics.accuracy_score(y_test,prediction_test ))
# Out:
# 0.9820359281437125

# %% [markdown]
# ## Model Evaluation

# %%
weights = pd.Series(model.coef_[0],
                    index=X.columns.values) 
print(weights.sort_values(ascending=False)[:10].plot(kind='bar'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(weights.sort_values(ascending=False)[-10:].plot(kind='bar'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig = plt.figure(figsize=(11,11))
cm = confusion_matrix(y_test, prediction_test, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=model.classes_)
disp.plot(cmap='gray')
plt.show()
